# %%
from __future__ import print_function
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image
import numpy as np
from matplotlib import pyplot as plt
from IPython.core.debugger import set_trace
import random
from IPython.display import Image
import torchaudio
import librosa
import matplotlib.pyplot as plt
import librosa.display
import glob
import os.path
import IPython
import random
# Out:
# /home/kchow/.conda/envs/SpeechVAE/lib/python2.7/site-packages/sklearn/utils/fixes.py:313: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   _nan_object_mask = _nan_object_array != _nan_object_array

# %%
# try a dataset, save all spectrograms somewhere
filenames = glob.glob("/home/kchow/datasets/clips/*.mp3")
cqt_clips = []

restart = False

number_of_clips = 10

# if numpy loaded 
if not restart and os.path.isfile('cqt_clips_.npy'):
    cqt_clips = np.load('cqt_clips_.npy')
else:
    for f in filenames:
        print(f)
        y, sr = librosa.load(f)
        C = np.abs(librosa.cqt(y, sr=sr))
        C = C[:84,:1939]
        if np.shape(C)[0] != 84 or np.shape(C)[1] != 1939:
            continue
        cqt_clips.append(C)
        if len(cqt_clips) == number_of_clips:
            break

np.save('cqt_clips_.npy', np.array(cqt_clips))

# %%
batch_size = 8
epochs = 100
no_cuda = False
seed = 1
beta = 0
log_interval = 1000
cuda = not no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}
loss_function_type = 'Beta' # [DIP-VAE1, 'DIP-VAE2, Beta']
latent_dimensions = 128
fc_dimensions = 512

# %%
torch.manual_seed
device = torch.device("cuda" if cuda else "cpu")

# %%
time_steps = 1939
freq_filters = 84
variable = 967
class MusicCQTAE(nn.Module):
    def __init__(self):
        super(MusicCQTAE, self).__init__()
        # in horizontal mode 
        self.conv1 = nn.Conv1d(1, 64, kernel_size=freq_filters, stride=freq_filters)
        #self.conv1 = nn.Conv1d(1, 64, kernel_size=time_steps, stride=time_steps)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=3, stride=2)
        self.conv3 = nn.Conv1d(128, 256, kernel_size=3, stride=1)
        
        #self.mu_i = nn.Linear(fc_dimensions, latent_dimensions)
        #self.var_i = nn.Linear(fc_dimensions, latent_dimensions)
        # stride 1 1935
        self.fc1 = nn.Linear(256*variable, fc_dimensions)
        self.fc2 = nn.Linear(latent_dimensions, fc_dimensions)
        self.fc3 = nn.Linear(fc_dimensions, 256*variable)
 
        #self.deconv1 = nn.ConvTranspose1d(256, 128, kernel_size=3, stride=2)
        self.deconv1 = nn.ConvTranspose1d(256, 128, kernel_size=3, stride=1) #to get same size, just kernel+1
        self.deconv2 = nn.ConvTranspose1d(128, 64, kernel_size=3, stride=2)
        self.deconv3 = nn.ConvTranspose1d(64, 1, kernel_size=freq_filters, stride=freq_filters)
        #self.deconv3 = nn.ConvTranspose1d(64, 1, kernel_size=time_steps, stride=time_steps)
    
    def encode(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        #set_trace()
        x = x.view(x.size(0), -1)
        x = F.tanh(self.fc1(x))
        return x
        #return self.mu_i(x), self.var_i(x)
    
    def decode(self, z):
        z = F.relu(self.fc3(z))
        z = z.view(z.size(0), 256, variable)
        z = F.relu(self.deconv1(z))
        z = F.relu(self.deconv2(z))
        z = F.tanh(self.deconv3(z))
        return z
    
    def forward(self, x):
        x = self.encode(x)
        return self.decode(x)

# %%
time_steps = 1939
freq_filters = 84
variable = 967
class MusicCQTVAE(nn.Module):
    def __init__(self):
        super(MusicCQTVAE, self).__init__()
        # in horizontal mode 
        self.conv1 = nn.Conv1d(1, 64, kernel_size=freq_filters, stride=freq_filters)
        #self.conv1 = nn.Conv1d(1, 64, kernel_size=time_steps, stride=time_steps)
        self.conv2 = nn.Conv1d(64, 128, kernel_size=3, stride=2)
        self.conv3 = nn.Conv1d(128, 256, kernel_size=3, stride=1)
        
        self.mu_i = nn.Linear(fc_dimensions, latent_dimensions)
        self.var_i = nn.Linear(fc_dimensions, latent_dimensions)
        
        self.fc1 = nn.Linear(256*variable, fc_dimensions)
        self.fc2 = nn.Linear(latent_dimensions, fc_dimensions)
        self.fc3 = nn.Linear(fc_dimensions, 256*variable)
 
        #self.deconv1 = nn.ConvTranspose1d(256, 128, kernel_size=3, stride=2)
        self.deconv1 = nn.ConvTranspose1d(256, 128, kernel_size=3, stride=1) #to get same size, just kernel+1
        self.deconv2 = nn.ConvTranspose1d(128, 64, kernel_size=3, stride=2)
        self.deconv3 = nn.ConvTranspose1d(64, 1, kernel_size=freq_filters, stride=freq_filters)
        #self.deconv3 = nn.ConvTranspose1d(64, 1, kernel_size=time_steps, stride=time_steps)
    
    def encode(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = x.view(x.size(0), -1)
        x = F.tanh(self.fc1(x))
        return self.mu_i(x), self.var_i(x)
    
    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return eps.mul(std).add_(mu)
    
    def decode(self, z):
        z = F.relu(self.fc2(z))
        z = F.relu(self.fc3(z))
        z = z.view(z.size(0), 256, variable)
        z = F.relu(self.deconv1(z))
        z = F.relu(self.deconv2(z))
        z = F.tanh(self.deconv3(z))
        return z
    
    def forward(self, x):
        mu, logvar = self.encode(x)
        
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
model = MusicCQTVAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-2)
#optimizer = optim.SGD(model.parameters(), lr=1e-3)

def loss_function(recon_x, x, mu, logvar):
    if loss_function_type == 'DIP-VAE1':
        return DIP_1_loss_function(recon_x, x, mu, logvar)
    elif loss_function_type == 'DIP-VAE2':
        return DIP_2_loss_function(recon_x, x, mu, logvar)
    elif loss_function_type == 'Beta':
        return beta_loss_function(recon_x, x, mu, logvar)

def beta_loss_function(recon_x, x, mu, logvar):
    MSE = F.mse_loss(recon_x, x)
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return MSE + (beta*(KLD)/recon_x.size(0))
    

def DIP_1_loss_function(recon_x, x, mu, logvar):
    exp_mu = mu.mean(0)
    # should this mu be on the 0th or 1st axis?
    mu_expand1 = mu.unsqueeze(1)
    mu_expand2 = mu.unsqueeze(2)
    exp_mu_mu_t = (mu_expand1 * mu_expand2).mean(0)
    cov = exp_mu_mu_t - exp_mu.unsqueeze(0) * exp_mu.unsqueeze(1)
    # diag = diagonal matrix returned, diag_part just the diagonal (diagonal)
    diag_part = torch.diagonal(cov) 
    off_diag_part = cov - torch.diag(diag_part)

    regulariser_od = lambda_od * (off_diag_part**2).sum()
    regulariser_d = lambda_d * ((diag_part - 1)**2).sum()
    dip_vae_regulariser = regulariser_d + regulariser_od
    return dip_vae_regulariser + beta_loss_function(recon_x, x, mu, logvar)


def DIP_2_loss_function(recon_x, x, mu, logvar):
    sigma = torch.diag(logvar)
    exp_cov = sigma.mean(0)
    
    exp_mu = mu.mean(0)
    mu_expand1 = mu.unsqueeze(1)
    mu_expand2 = mu.unsqueeze(2)
    exp_mu_mu_t = (mu_expand1 * mu_expand2).mean(0)
    
    cov_exp = exp_mu_mu_t - exp_mu.unsqueeze(0) * exp_mu.unsqueeze(1)
    cov_z = cov_exp + exp_cov
    
    diag_part = torch.diagonal(cov_z)
    off_diag_part = cov_z - torch.diag(diag_part)
    
    regulariser_od = lambda_od * (off_diag_part**2).sum()
    regulariser_d = lambda_d * ((diag_part - 1)**2).sum()
    dip_vae_regulariser = regulariser_d + regulariser_od
    return dip_vae_regulariser + beta_loss_function(recon_x, x, mu, logvar)
# code from https://stackoverflow.com/questions/8290397/how-to-split-an-iterable-in-constant-size-chunks
def data_batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]
average_losses = []
def train(epoch):
    model.train()
    train_loss = 0
    subset_data = spectrogram_clips[8:16]
    import random
    random.shuffle(subset_data)
    # shuffle subset
    for data in data_batch(subset_data, batch_size):
        # update this to use a larger batch size 
        data = np.array(data)
        # data columns not consistent
        #data = data[:freq_filters,:time_steps]
        #if np.shape(data)[0] != freq_filters or np.shape(data)[1] != time_steps:
            #continue
        data = torch.from_numpy(data)
        #set_trace()
        # how data is set up here MATTERS. Double check with patrick 
        #set_trace()
        data = torch.transpose(data, 1, 2)
        data = data.contiguous().view(data.size(0), -1, freq_filters*time_steps)
        data = data.to(device, dtype=torch.float)
        optimizer.zero_grad()
        recon_batch, mu, logvar = model(data)
        loss = loss_function(recon_batch, data, mu, logvar)# /data.size(0)
        loss.backward()
        #use clip here 
        #clip_gradient = 2
        #nn.utils.clip_grad_norm_(model.parameters(), clip_gradient)
        #set_trace()
        train_loss += loss.item()
        optimizer.step()
        print(epoch, loss.item())
    average_loss = train_loss #/ len(subset_data)
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, average_loss))#len(mel_spectrogram_clips)))
    average_losses.append(average_loss)

    
    
def save_checkpoint(state, filename='checkpoint.pth.tar'):
    torch.save(state, filename)

# %%
model = MusicCQTAE().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-2)
#optimizer = optim.SGD(model.parameters(), lr=1e-3)
average_losses = []

def loss_function(recon_x, x):
    #MSE = F.mse_loss(recon_x, x, reduction='sum')
    MSE = F.mse_loss(recon_x, x)
    return MSE 

# code from https://stackoverflow.com/questions/8290397/how-to-split-an-iterable-in-constant-size-chunks
def data_batch(iterable, n=1):
    l = len(iterable)
    for ndx in range(0, l, n):
        yield iterable[ndx:min(ndx + n, l)]

def train(epoch):
    model.train()
    train_loss = 0
    subset_data = cqt_clips[9:10]
    random.shuffle(subset_data)
    # shuffle subset
    for data in data_batch(subset_data, batch_size):
        # update this to use a larger batch size 
        data = np.array(data)
        # data columns not consistent
        #data = data[:freq_filters,:time_steps]
        #if np.shape(data)[0] != freq_filters or np.shape(data)[1] != time_steps:
            #continue
        data = torch.from_numpy(data)
        #set_trace()
        # how data is set up here MATTERS. Double check with patrick 
        #set_trace()
        data = torch.transpose(data, 1, 2)
        data = data.contiguous().view(data.size(0), -1, freq_filters*time_steps)
        data = data.to(device, dtype=torch.float)
        optimizer.zero_grad()
        recon_batch = model(data)
        loss = loss_function(recon_batch, data) #/data.size(0)
        loss.backward()
        #use clip here 
        #clip_gradient = 2
        #nn.utils.clip_grad_norm_(model.parameters(), clip_gradient)
        #set_trace()
        train_loss += loss.item()
        optimizer.step()
        print(epoch, loss.item())
    average_loss = train_loss #/ len(subset_data)
    print('====> Epoch: {} Average loss: {:.4f}'.format(epoch, average_loss))#len(mel_spectrogram_clips)))
    average_losses.append(average_loss)

def save_checkpoint(state, filename='checkpoint.pth.tar'):
    torch.save(state, filename)

# %%
for epoch in range(1, 1000):
    train(epoch)
plt.figure(1)
plt.plot(average_losses)
plt.show()
# Out:
# 1 0.0860662311316
# ====> Epoch: 1 Average loss: 0.0861
# 2 0.0748395994306
# ====> Epoch: 2 Average loss: 0.0748
# 3 0.440663486719
# ====> Epoch: 3 Average loss: 0.4407
# 4 0.0752854794264
# ====> Epoch: 4 Average loss: 0.0753
# 5 0.0758820176125
# ====> Epoch: 5 Average loss: 0.0759
# 6 0.0749038383365
# ====> Epoch: 6 Average loss: 0.0749
# 7 0.0732677802444
# ====> Epoch: 7 Average loss: 0.0733
# 8 0.0712029710412
# ====> Epoch: 8 Average loss: 0.0712
# 9 0.0684548541903
# ====> Epoch: 9 Average loss: 0.0685
# 10 0.0620024986565
# ====> Epoch: 10 Average loss: 0.0620
# 11 0.0536869168282
# ====> Epoch: 11 Average loss: 0.0537
# 12 0.0491618402302
# ====> Epoch: 12 Average loss: 0.0492
# 13 0.0463790781796
# ====> Epoch: 13 Average loss: 0.0464
# 14 0.0443310663104
# ====> Epoch: 14 Average loss: 0.0443
# 15 0.0432454012334
# ====> Epoch: 15 Average loss: 0.0432
# 16 0.0430548861623
# ====> Epoch: 16 Average loss: 0.0431
# 17 0.0430180840194
# ====> Epoch: 17 Average loss: 0.0430
# 18 0.0428238064051
# ====> Epoch: 18 Average loss: 0.0428
# 19 0.0427072234452
# ====> Epoch: 19 Average loss: 0.0427
# 20 0.0426773950458
# ====> Epoch: 20 Average loss: 0.0427
# 21 0.042282897979
# ====> Epoch: 21 Average loss: 0.0423
# 22 0.0417960733175
# ====> Epoch: 22 Average loss: 0.0418
# 23 0.0413867682219
# ====> Epoch: 23 Average loss: 0.0414
# 24 0.0410426110029
# ====> Epoch: 24 Average loss: 0.0410
# 25 0.0406441166997
# ====> Epoch: 25 Average loss: 0.0406
# 26 0.0402922220528
# ====> Epoch: 26 Average loss: 0.0403
# 27 0.0400825366378
# ====> Epoch: 27 Average loss: 0.0401
# 28 0.0399283394217
# ====> Epoch: 28 Average loss: 0.0399
# 29 0.0397175215185
# ====> Epoch: 29 Average loss: 0.0397
# 30 0.0394814871252
# ====> Epoch: 30 Average loss: 0.0395
# 31 0.0392279960215
# ====> Epoch: 31 Average loss: 0.0392
# 32 0.0389727093279
# ====> Epoch: 32 Average loss: 0.0390
# 33 0.0387205146253
# ====> Epoch: 33 Average loss: 0.0387
# 34 0.0384565107524
# ====> Epoch: 34 Average loss: 0.0385
# 35 0.0381739772856
# ====> Epoch: 35 Average loss: 0.0382
# 36 0.0378988273442
# ====> Epoch: 36 Average loss: 0.0379
# 37 0.0376549139619
# ====> Epoch: 37 Average loss: 0.0377
# 38 0.0374300405383
# ====> Epoch: 38 Average loss: 0.0374
# 39 0.0372129790485
# ====> Epoch: 39 Average loss: 0.0372
# 40 0.0370060279965
# ====> Epoch: 40 Average loss: 0.0370
# 41 0.0368153937161
# ====> Epoch: 41 Average loss: 0.0368
# 42 0.0366188809276
# ====> Epoch: 42 Average loss: 0.0366
# 43 0.0364320352674
# ====> Epoch: 43 Average loss: 0.0364
# 44 0.0362298600376
# ====> Epoch: 44 Average loss: 0.0362
# 45 0.0360058322549
# ====> Epoch: 45 Average loss: 0.0360
# 46 0.0357658416033
# ====> Epoch: 46 Average loss: 0.0358
# 47 0.0355201512575
# ====> Epoch: 47 Average loss: 0.0355
# 48 0.0352865420282
# ====> Epoch: 48 Average loss: 0.0353
# 49 0.0350604616106
# ====> Epoch: 49 Average loss: 0.0351
# 50 0.0348325297236
# ====> Epoch: 50 Average loss: 0.0348
# 51 0.0346012189984
# ====> Epoch: 51 Average loss: 0.0346
# 52 0.0343581698835
# ====> Epoch: 52 Average loss: 0.0344
# 53 0.0340993851423
# ====> Epoch: 53 Average loss: 0.0341
# 54 0.0338345021009
# ====> Epoch: 54 Average loss: 0.0338
# 55 0.0336085148156
# ====> Epoch: 55 Average loss: 0.0336
# 56 0.0333555117249
# ====> Epoch: 56 Average loss: 0.0334
# 57 0.0331298746169
# ====> Epoch: 57 Average loss: 0.0331
# 58 0.0328953638673
# ====> Epoch: 58 Average loss: 0.0329
# 59 0.0326501317322
# ====> Epoch: 59 Average loss: 0.0327
# 60 0.0324159264565
# ====> Epoch: 60 Average loss: 0.0324
# 61 0.0322057716548
# ====> Epoch: 61 Average loss: 0.0322
# 62 0.0319975689054
# ====> Epoch: 62 Average loss: 0.0320
# 63 0.0317940786481
# ====> Epoch: 63 Average loss: 0.0318
# 64 0.0315960012376
# ====> Epoch: 64 Average loss: 0.0316
# 65 0.0314036421478
# ====> Epoch: 65 Average loss: 0.0314
# 66 0.0312125887722
# ====> Epoch: 66 Average loss: 0.0312
# 67 0.0310382600874
# ====> Epoch: 67 Average loss: 0.0310
# 68 0.0308673810214
# ====> Epoch: 68 Average loss: 0.0309
# 69 0.0307073201984
# ====> Epoch: 69 Average loss: 0.0307
# 70 0.0305564254522
# ====> Epoch: 70 Average loss: 0.0306
# 71 0.0303969308734
# ====> Epoch: 71 Average loss: 0.0304
# 72 0.0302411075681
# ====> Epoch: 72 Average loss: 0.0302
# 73 0.0300985779613
# ====> Epoch: 73 Average loss: 0.0301
# 74 0.029958633706
# ====> Epoch: 74 Average loss: 0.0300
# 75 0.0298333149403
# ====> Epoch: 75 Average loss: 0.0298
# 76 0.0296983327717
# ====> Epoch: 76 Average loss: 0.0297
# 77 0.0295617692173
# ====> Epoch: 77 Average loss: 0.0296
# 78 0.0294289290905
# ====> Epoch: 78 Average loss: 0.0294
# 79 0.0292962267995
# ====> Epoch: 79 Average loss: 0.0293
# 80 0.0291573181748
# ====> Epoch: 80 Average loss: 0.0292
# 81 0.0290271267295
# ====> Epoch: 81 Average loss: 0.0290
# 82 0.0289059821516
# ====> Epoch: 82 Average loss: 0.0289
# 83 0.0287643838674
# ====> Epoch: 83 Average loss: 0.0288
# 84 0.0286425109953
# ====> Epoch: 84 Average loss: 0.0286
# 85 0.0285107977688
# ====> Epoch: 85 Average loss: 0.0285
# 86 0.0283804014325
# ====> Epoch: 86 Average loss: 0.0284
# 87 0.0282526928931
# ====> Epoch: 87 Average loss: 0.0283
# 88 0.0281277019531
# ====> Epoch: 88 Average loss: 0.0281
# 89 0.0280143804848
# ====> Epoch: 89 Average loss: 0.0280
# 90 0.0279111154377
# ====> Epoch: 90 Average loss: 0.0279
# 91 0.0277999956161
# ====> Epoch: 91 Average loss: 0.0278
# 92 0.0276741366833
# ====> Epoch: 92 Average loss: 0.0277
# 93 0.0275766719133
# ====> Epoch: 93 Average loss: 0.0276
# 94 0.0274728685617
# ====> Epoch: 94 Average loss: 0.0275
# 95 0.0273684710264
# ====> Epoch: 95 Average loss: 0.0274
# 96 0.0272750630975
# ====> Epoch: 96 Average loss: 0.0273
# 97 0.0271832682192
# ====> Epoch: 97 Average loss: 0.0272
# 98 0.0270922593772
# ====> Epoch: 98 Average loss: 0.0271
# 99 0.0270036049187
# ====> Epoch: 99 Average loss: 0.0270
# 100 0.0269211046398
# ====> Epoch: 100 Average loss: 0.0269
# 101 0.0268386323005
# ====> Epoch: 101 Average loss: 0.0268
# 102 0.0267603993416
# ====> Epoch: 102 Average loss: 0.0268
# 103 0.0266880821437
# ====> Epoch: 103 Average loss: 0.0267
# 104 0.0266081206501
# ====> Epoch: 104 Average loss: 0.0266
# 105 0.0265317894518
# ====> Epoch: 105 Average loss: 0.0265
# 106 0.0264535676688
# ====> Epoch: 106 Average loss: 0.0265
# 107 0.0263799168169
# ====> Epoch: 107 Average loss: 0.0264
# 108 0.0263080876321
# ====> Epoch: 108 Average loss: 0.0263
# 109 0.026242595166
# ====> Epoch: 109 Average loss: 0.0262
# 110 0.0261738430709
# ====> Epoch: 110 Average loss: 0.0262
# 111 0.0261119361967
# ====> Epoch: 111 Average loss: 0.0261
# 112 0.0260562989861
# ====> Epoch: 112 Average loss: 0.0261
# 113 0.0259860809892
# ====> Epoch: 113 Average loss: 0.0260
# 114 0.0259233489633
# ====> Epoch: 114 Average loss: 0.0259
# 115 0.025867741555
# ====> Epoch: 115 Average loss: 0.0259
# 116 0.0258096698672
# ====> Epoch: 116 Average loss: 0.0258
# 117 0.0257364716381
# ====> Epoch: 117 Average loss: 0.0257
# 118 0.025683959946
# ====> Epoch: 118 Average loss: 0.0257
# 119 0.0256202854216
# ====> Epoch: 119 Average loss: 0.0256
# 120 0.0255578886718
# ====> Epoch: 120 Average loss: 0.0256
# 121 0.025496808812
# ====> Epoch: 121 Average loss: 0.0255
# 122 0.0254356227815
# ====> Epoch: 122 Average loss: 0.0254
# 123 0.0253710430115
# ====> Epoch: 123 Average loss: 0.0254
# 124 0.0253107380122
# ====> Epoch: 124 Average loss: 0.0253
# 125 0.0252631250769
# ====> Epoch: 125 Average loss: 0.0253
# 126 0.025218391791
# ====> Epoch: 126 Average loss: 0.0252
# 127 0.0251696817577
# ====> Epoch: 127 Average loss: 0.0252
# 128 0.0251371767372
# ====> Epoch: 128 Average loss: 0.0251
# 129 0.02510808222
# ====> Epoch: 129 Average loss: 0.0251
# 130 0.0250446908176
# ====> Epoch: 130 Average loss: 0.0250
# 131 0.024955548346
# ====> Epoch: 131 Average loss: 0.0250
# 132 0.0248883366585
# ====> Epoch: 132 Average loss: 0.0249
# 133 0.0248369667679
# ====> Epoch: 133 Average loss: 0.0248
# 134 0.0247982256114
# ====> Epoch: 134 Average loss: 0.0248
# 135 0.0247197560966
# ====> Epoch: 135 Average loss: 0.0247
# 136 0.024675918743
# ====> Epoch: 136 Average loss: 0.0247
# 137 0.0246349703521
# ====> Epoch: 137 Average loss: 0.0246
# 138 0.0245824232697
# ====> Epoch: 138 Average loss: 0.0246
# 139 0.0245173629373
# ====> Epoch: 139 Average loss: 0.0245
# 140 0.0244564563036
# ====> Epoch: 140 Average loss: 0.0245
# 141 0.0244373586029
# ====> Epoch: 141 Average loss: 0.0244
# 142 0.0243808124214
# ====> Epoch: 142 Average loss: 0.0244
# 143 0.0243317298591
# ====> Epoch: 143 Average loss: 0.0243
# 144 0.0242719724774
# ====> Epoch: 144 Average loss: 0.0243
# 145 0.0242220256478
# ====> Epoch: 145 Average loss: 0.0242
# 146 0.0241686739028
# ====> Epoch: 146 Average loss: 0.0242
# 147 0.0241439696401
# ====> Epoch: 147 Average loss: 0.0241
# 148 0.0241072624922
# ====> Epoch: 148 Average loss: 0.0241
# 149 0.0240648854524
# ====> Epoch: 149 Average loss: 0.0241
# 150 0.0240097157657
# ====> Epoch: 150 Average loss: 0.0240
# 151 0.0239723194391
# ====> Epoch: 151 Average loss: 0.0240
# 152 0.0239174533635
# ====> Epoch: 152 Average loss: 0.0239
# 153 0.0238831341267
# ====> Epoch: 153 Average loss: 0.0239
# 154 0.0238472018391
# ====> Epoch: 154 Average loss: 0.0238
# 155 0.0238146949559
# ====> Epoch: 155 Average loss: 0.0238
# 156 0.023793252185
# ====> Epoch: 156 Average loss: 0.0238
# 157 0.0237635616213
# ====> Epoch: 157 Average loss: 0.0238
# 158 0.0237434860319
# ====> Epoch: 158 Average loss: 0.0237
# 159 0.0237255617976
# ====> Epoch: 159 Average loss: 0.0237
# 160 0.0236957874149
# ====> Epoch: 160 Average loss: 0.0237
# 161 0.0236364752054
# ====> Epoch: 161 Average loss: 0.0236
# 162 0.0235942285508
# ====> Epoch: 162 Average loss: 0.0236
# 163 0.0235404595733
# ====> Epoch: 163 Average loss: 0.0235
# 164 0.0235162116587
# ====> Epoch: 164 Average loss: 0.0235
# 165 0.0235009323806
# ====> Epoch: 165 Average loss: 0.0235
# 166 0.0234820656478
# ====> Epoch: 166 Average loss: 0.0235
# 167 0.0234241262078
# ====> Epoch: 167 Average loss: 0.0234
# 168 0.0233748443425
# ====> Epoch: 168 Average loss: 0.0234
# 169 0.0233470983803
# ====> Epoch: 169 Average loss: 0.0233
# 170 0.0233311597258
# ====> Epoch: 170 Average loss: 0.0233
# 171 0.0232961811125
# ====> Epoch: 171 Average loss: 0.0233
# 172 0.0232748482376
# ====> Epoch: 172 Average loss: 0.0233
# 173 0.0232307743281
# ====> Epoch: 173 Average loss: 0.0232
# 174 0.0232040975243
# ====> Epoch: 174 Average loss: 0.0232
# 175 0.0231818519533
# ====> Epoch: 175 Average loss: 0.0232
# 176 0.023162856698
# ====> Epoch: 176 Average loss: 0.0232
# 177 0.0231371968985
# ====> Epoch: 177 Average loss: 0.0231
# 178 0.023096518591
# ====> Epoch: 178 Average loss: 0.0231
# 179 0.0230596065521
# ====> Epoch: 179 Average loss: 0.0231
# 180 0.0230359509587
# ====> Epoch: 180 Average loss: 0.0230
# 181 0.0230098441243
# ====> Epoch: 181 Average loss: 0.0230
# 182 0.0229872148484
# ====> Epoch: 182 Average loss: 0.0230
# 183 0.0229690279812
# ====> Epoch: 183 Average loss: 0.0230
# 184 0.0229435563087
# ====> Epoch: 184 Average loss: 0.0229
# 185 0.0229124780744
# ====> Epoch: 185 Average loss: 0.0229
# 186 0.0229034330696
# ====> Epoch: 186 Average loss: 0.0229
# 187 0.0228697191924
# ====> Epoch: 187 Average loss: 0.0229
# 188 0.022855617106
# ====> Epoch: 188 Average loss: 0.0229
# 189 0.0228260327131
# ====> Epoch: 189 Average loss: 0.0228
# 190 0.0227877050638
# ====> Epoch: 190 Average loss: 0.0228
# 191 0.0227686688304
# ====> Epoch: 191 Average loss: 0.0228
# 192 0.0227458588779
# ====> Epoch: 192 Average loss: 0.0227
# 193 0.0227172970772
# ====> Epoch: 193 Average loss: 0.0227
# 194 0.0226985178888
# ====> Epoch: 194 Average loss: 0.0227
# 195 0.0226913392544
# ====> Epoch: 195 Average loss: 0.0227
# 196 0.0227080918849
# ====> Epoch: 196 Average loss: 0.0227
# 197 0.022701965645
# ====> Epoch: 197 Average loss: 0.0227
# 198 0.0226911269128
# ====> Epoch: 198 Average loss: 0.0227
# 199 0.0226185936481
# ====> Epoch: 199 Average loss: 0.0226
# 200 0.0225692801178
# ====> Epoch: 200 Average loss: 0.0226
# 201 0.0225567277521
# ====> Epoch: 201 Average loss: 0.0226
# 202 0.0225598886609
# ====> Epoch: 202 Average loss: 0.0226
# 203 0.0225497893989
# ====> Epoch: 203 Average loss: 0.0225
# 204 0.0225037131459
# ====> Epoch: 204 Average loss: 0.0225
# 205 0.0224747397006
# ====> Epoch: 205 Average loss: 0.0225
# 206 0.0224537961185
# ====> Epoch: 206 Average loss: 0.0225
# 207 0.022456491366
# ====> Epoch: 207 Average loss: 0.0225
# 208 0.0224789585918
# ====> Epoch: 208 Average loss: 0.0225
# 209 0.0224773455411
# ====> Epoch: 209 Average loss: 0.0225
# 210 0.0224566049874
# ====> Epoch: 210 Average loss: 0.0225
# 211 0.0224120430648
# ====> Epoch: 211 Average loss: 0.0224
# 212 0.0223501455039
# ====> Epoch: 212 Average loss: 0.0224
# 213 0.0223215930164
# ====> Epoch: 213 Average loss: 0.0223
# 214 0.022317070514
# ====> Epoch: 214 Average loss: 0.0223
# 215 0.0223355256021
# ====> Epoch: 215 Average loss: 0.0223
# 216 0.0223177112639
# ====> Epoch: 216 Average loss: 0.0223
# 217 0.0222754199058
# ====> Epoch: 217 Average loss: 0.0223
# 218 0.022233190015
# ====> Epoch: 218 Average loss: 0.0222
# 219 0.022202949971
# ====> Epoch: 219 Average loss: 0.0222
# 220 0.0221909526736
# ====> Epoch: 220 Average loss: 0.0222
# 221 0.0221932101995
# ====> Epoch: 221 Average loss: 0.0222
# 222 0.0221843775362
# ====> Epoch: 222 Average loss: 0.0222
# 223 0.0221467539668
# ====> Epoch: 223 Average loss: 0.0221
# 224 0.0221073664725
# ====> Epoch: 224 Average loss: 0.0221
# 225 0.0221259277314
# ====> Epoch: 225 Average loss: 0.0221
# 226 0.0221335962415
# ====> Epoch: 226 Average loss: 0.0221
# 227 0.0221076011658
# ====> Epoch: 227 Average loss: 0.0221
# 228 0.0220897812396
# ====> Epoch: 228 Average loss: 0.0221
# 229 0.0220673587173
# ====> Epoch: 229 Average loss: 0.0221
# 230 0.0220449436456
# ====> Epoch: 230 Average loss: 0.0220
# 231 0.0220278222114
# ====> Epoch: 231 Average loss: 0.0220
# 232 0.0220174621791
# ====> Epoch: 232 Average loss: 0.0220
# 233 0.0219956617802
# ====> Epoch: 233 Average loss: 0.0220
# 234 0.0219920538366
# ====> Epoch: 234 Average loss: 0.0220
# 235 0.0219691675156
# ====> Epoch: 235 Average loss: 0.0220
# 236 0.0219627805054
# ====> Epoch: 236 Average loss: 0.0220
# 237 0.0219794306904
# ====> Epoch: 237 Average loss: 0.0220
# 238 0.0219718944281
# ====> Epoch: 238 Average loss: 0.0220
# 239 0.0219810586423
# ====> Epoch: 239 Average loss: 0.0220
# 240 0.0219756998122
# ====> Epoch: 240 Average loss: 0.0220
# 241 0.0219962373376
# ====> Epoch: 241 Average loss: 0.0220
# 242 0.0219446793199
# ====> Epoch: 242 Average loss: 0.0219
# 243 0.0218842253089
# ====> Epoch: 243 Average loss: 0.0219
# 244 0.0218036267906
# ====> Epoch: 244 Average loss: 0.0218
# 245 0.0217923764139
# ====> Epoch: 245 Average loss: 0.0218
# 246 0.0217988453805
# ====> Epoch: 246 Average loss: 0.0218
# 247 0.0217828676105
# ====> Epoch: 247 Average loss: 0.0218
# 248 0.0217649098486
# ====> Epoch: 248 Average loss: 0.0218
# 249 0.02174683474
# ====> Epoch: 249 Average loss: 0.0217
# 250 0.0217182319611
# ====> Epoch: 250 Average loss: 0.0217
# 251 0.0216991808265
# ====> Epoch: 251 Average loss: 0.0217
# 252 0.0216789282858
# ====> Epoch: 252 Average loss: 0.0217
# 253 0.0216797664762
# ====> Epoch: 253 Average loss: 0.0217
# 254 0.0216686781496
# ====> Epoch: 254 Average loss: 0.0217
# 255 0.0216493718326
# ====> Epoch: 255 Average loss: 0.0216
# 256 0.0216102134436
# ====> Epoch: 256 Average loss: 0.0216
# 257 0.0216228887439
# ====> Epoch: 257 Average loss: 0.0216
# 258 0.0216047428548
# ====> Epoch: 258 Average loss: 0.0216
# 259 0.0215886831284
# ====> Epoch: 259 Average loss: 0.0216
# 260 0.0215802881867
# ====> Epoch: 260 Average loss: 0.0216
# 261 0.0215698052198
# ====> Epoch: 261 Average loss: 0.0216
# 262 0.0215662419796
# ====> Epoch: 262 Average loss: 0.0216
# 263 0.0215567816049
# ====> Epoch: 263 Average loss: 0.0216
# 264 0.0215393584222
# ====> Epoch: 264 Average loss: 0.0215
# 265 0.0215366240591
# ====> Epoch: 265 Average loss: 0.0215
# 266 0.0215220134705
# ====> Epoch: 266 Average loss: 0.0215
# 267 0.0215120464563
# ====> Epoch: 267 Average loss: 0.0215
# 268 0.0215032212436
# ====> Epoch: 268 Average loss: 0.0215
# 269 0.0214956626296
# ====> Epoch: 269 Average loss: 0.0215
# 270 0.0214844197035
# ====> Epoch: 270 Average loss: 0.0215
# 271 0.0214760266244
# ====> Epoch: 271 Average loss: 0.0215
# 272 0.0214661806822
# ====> Epoch: 272 Average loss: 0.0215
# 273 0.0214527957141
# ====> Epoch: 273 Average loss: 0.0215
# 274 0.0214340072125
# ====> Epoch: 274 Average loss: 0.0214
# 275 0.0214197710156
# ====> Epoch: 275 Average loss: 0.0214
# 276 0.0213878322393
# ====> Epoch: 276 Average loss: 0.0214
# 277 0.0213686656207
# ====> Epoch: 277 Average loss: 0.0214
# 278 0.0213589537889
# ====> Epoch: 278 Average loss: 0.0214
# 279 0.0213616266847
# ====> Epoch: 279 Average loss: 0.0214
# 280 0.0214341152459
# ====> Epoch: 280 Average loss: 0.0214
# 281 0.0213718116283
# ====> Epoch: 281 Average loss: 0.0214
# 282 0.0213981196284
# ====> Epoch: 282 Average loss: 0.0214
# 283 0.0214566532522
# ====> Epoch: 283 Average loss: 0.0215
# 284 0.0215350035578
# ====> Epoch: 284 Average loss: 0.0215
# 285 0.0215448178351
# ====> Epoch: 285 Average loss: 0.0215
# 286 0.0214829463512
# ====> Epoch: 286 Average loss: 0.0215
# 287 0.0213352423161
# ====> Epoch: 287 Average loss: 0.0213
# 288 0.0213025268167
# ====> Epoch: 288 Average loss: 0.0213
# 289 0.0213475450873
# ====> Epoch: 289 Average loss: 0.0213
# 290 0.0213331189007
# ====> Epoch: 290 Average loss: 0.0213
# 291 0.0212705750018
# ====> Epoch: 291 Average loss: 0.0213
# 292 0.0212533921003
# ====> Epoch: 292 Average loss: 0.0213
# 293 0.0212933160365
# ====> Epoch: 293 Average loss: 0.0213
# 294 0.0212545190006
# ====> Epoch: 294 Average loss: 0.0213
# 295 0.0211989786476
# ====> Epoch: 295 Average loss: 0.0212
# 296 0.0212091468275
# ====> Epoch: 296 Average loss: 0.0212
# 297 0.0212112125009
# ====> Epoch: 297 Average loss: 0.0212
# 298 0.0211808010936
# ====> Epoch: 298 Average loss: 0.0212
# 299 0.0211348831654
# ====> Epoch: 299 Average loss: 0.0211
# 300 0.0211448073387
# ====> Epoch: 300 Average loss: 0.0211
# 301 0.0211594365537
# ====> Epoch: 301 Average loss: 0.0212
# 302 0.0211403369904
# ====> Epoch: 302 Average loss: 0.0211
# 303 0.0211018230766
# ====> Epoch: 303 Average loss: 0.0211
# 304 0.0211041420698
# ====> Epoch: 304 Average loss: 0.0211
# 305 0.0210934616625
# ====> Epoch: 305 Average loss: 0.0211
# 306 0.021077780053
# ====> Epoch: 306 Average loss: 0.0211
# 307 0.0210632588714
# ====> Epoch: 307 Average loss: 0.0211
# 308 0.0210517104715
# ====> Epoch: 308 Average loss: 0.0211
# 309 0.0210530646145
# ====> Epoch: 309 Average loss: 0.0211
# 310 0.021044626832
# ====> Epoch: 310 Average loss: 0.0210
# 311 0.0210347399116
# ====> Epoch: 311 Average loss: 0.0210
# 312 0.0210191886872
# ====> Epoch: 312 Average loss: 0.0210
# 313 0.0210161488503
# ====> Epoch: 313 Average loss: 0.0210
# 314 0.0210090149194
# ====> Epoch: 314 Average loss: 0.0210
# 315 0.0209974665195
# ====> Epoch: 315 Average loss: 0.0210
# 316 0.0210112575442
# ====> Epoch: 316 Average loss: 0.0210
# 317 0.0210196543485
# ====> Epoch: 317 Average loss: 0.0210
# 318 0.0210461989045
# ====> Epoch: 318 Average loss: 0.0210
# 319 0.0210995916277
# ====> Epoch: 319 Average loss: 0.0211
# 320 0.0211489349604
# ====> Epoch: 320 Average loss: 0.0211
# 321 0.0211725868285
# ====> Epoch: 321 Average loss: 0.0212
# 322 0.0211148187518
# ====> Epoch: 322 Average loss: 0.0211
# 323 0.0210165251046
# ====> Epoch: 323 Average loss: 0.0210
# 324 0.0209622457623
# ====> Epoch: 324 Average loss: 0.0210
# 325 0.0209850464016
# ====> Epoch: 325 Average loss: 0.0210
# 326 0.0210132002831
# ====> Epoch: 326 Average loss: 0.0210
# 327 0.0209931135178
# ====> Epoch: 327 Average loss: 0.0210
# 328 0.0209274310619
# ====> Epoch: 328 Average loss: 0.0209
# 329 0.0209036972374
# ====> Epoch: 329 Average loss: 0.0209
# 330 0.0209277775139
# ====> Epoch: 330 Average loss: 0.0209
# 331 0.0209344718605
# ====> Epoch: 331 Average loss: 0.0209
# 332 0.0209103152156
# ====> Epoch: 332 Average loss: 0.0209
# 333 0.0208762325346
# ====> Epoch: 333 Average loss: 0.0209
# 334 0.0208570901304
# ====> Epoch: 334 Average loss: 0.0209
# 335 0.0208572857082
# ====> Epoch: 335 Average loss: 0.0209
# 336 0.0208646245301
# ====> Epoch: 336 Average loss: 0.0209
# 337 0.0208502598107
# ====> Epoch: 337 Average loss: 0.0209
# 338 0.0208337493241
# ====> Epoch: 338 Average loss: 0.0208
# 339 0.0208210293204
# ====> Epoch: 339 Average loss: 0.0208
# 340 0.0208103973418
# ====> Epoch: 340 Average loss: 0.0208
# 341 0.0208076629788
# ====> Epoch: 341 Average loss: 0.0208
# 342 0.0208202656358
# ====> Epoch: 342 Average loss: 0.0208
# 343 0.0208352934569
# ====> Epoch: 343 Average loss: 0.0208
# 344 0.0208181887865
# ====> Epoch: 344 Average loss: 0.0208
# 345 0.020800601691
# ====> Epoch: 345 Average loss: 0.0208
# 346 0.020793389529
# ====> Epoch: 346 Average loss: 0.0208
# 347 0.0207960885018
# ====> Epoch: 347 Average loss: 0.0208
# 348 0.0207997504622
# ====> Epoch: 348 Average loss: 0.0208
# 349 0.0207777861506
# ====> Epoch: 349 Average loss: 0.0208
# 350 0.0207670852542
# ====> Epoch: 350 Average loss: 0.0208
# 351 0.0207668170333
# ====> Epoch: 351 Average loss: 0.0208
# 352 0.0207592714578
# ====> Epoch: 352 Average loss: 0.0208
# 353 0.0207648612559
# ====> Epoch: 353 Average loss: 0.0208
# 354 0.0207571629435
# ====> Epoch: 354 Average loss: 0.0208
# 355 0.0207427889109
# ====> Epoch: 355 Average loss: 0.0207
# 356 0.0207401849329
# ====> Epoch: 356 Average loss: 0.0207
# 357 0.0207334849983
# ====> Epoch: 357 Average loss: 0.0207
# 358 0.0207270961255
# ====> Epoch: 358 Average loss: 0.0207
# 359 0.0207336060703
# ====> Epoch: 359 Average loss: 0.0207
# 360 0.0207462050021
# ====> Epoch: 360 Average loss: 0.0207
# 361 0.0207648724318
# ====> Epoch: 361 Average loss: 0.0208
# 362 0.0207973141223
# ====> Epoch: 362 Average loss: 0.0208
# 363 0.0208304468542
# ====> Epoch: 363 Average loss: 0.0208
# 364 0.0208394508809
# ====> Epoch: 364 Average loss: 0.0208
# 365 0.0208123270422
# ====> Epoch: 365 Average loss: 0.0208
# 366 0.0207462217659
# ====> Epoch: 366 Average loss: 0.0207
# 367 0.0206776130944
# ====> Epoch: 367 Average loss: 0.0207
# 368 0.0206533838063
# ====> Epoch: 368 Average loss: 0.0207
# 369 0.020679242909
# ====> Epoch: 369 Average loss: 0.0207
# 370 0.0207117330283
# ====> Epoch: 370 Average loss: 0.0207
# 371 0.0206909496337
# ====> Epoch: 371 Average loss: 0.0207
# 372 0.0206394009292
# ====> Epoch: 372 Average loss: 0.0206
# 373 0.0206093899906
# ====> Epoch: 373 Average loss: 0.0206
# 374 0.0206115357578
# ====> Epoch: 374 Average loss: 0.0206
# 375 0.0206330120564
# ====> Epoch: 375 Average loss: 0.0206
# 376 0.0206341650337
# ====> Epoch: 376 Average loss: 0.0206
# 377 0.0206034872681
# ====> Epoch: 377 Average loss: 0.0206
# 378 0.0205735564232
# ====> Epoch: 378 Average loss: 0.0206
# 379 0.0205609463155
# ====> Epoch: 379 Average loss: 0.0206
# 380 0.0205633156002
# ====> Epoch: 380 Average loss: 0.0206
# 381 0.020570339635
# ====> Epoch: 381 Average loss: 0.0206
# 382 0.0205641239882
# ====> Epoch: 382 Average loss: 0.0206
# 383 0.0205528177321
# ====> Epoch: 383 Average loss: 0.0206
# 384 0.0205428265035
# ====> Epoch: 384 Average loss: 0.0205
# 385 0.0205177590251
# ====> Epoch: 385 Average loss: 0.0205
# 386 0.0205247048289
# ====> Epoch: 386 Average loss: 0.0205
# 387 0.0205294378102
# ====> Epoch: 387 Average loss: 0.0205
# 388 0.0205602012575
# ====> Epoch: 388 Average loss: 0.0206
# 389 0.0205748211592
# ====> Epoch: 389 Average loss: 0.0206
# 390 0.0205850061029
# ====> Epoch: 390 Average loss: 0.0206
# 391 0.0206245705485
# ====> Epoch: 391 Average loss: 0.0206
# 392 0.0206091217697
# ====> Epoch: 392 Average loss: 0.0206
# 393 0.0205925777555
# ====> Epoch: 393 Average loss: 0.0206
# 394 0.0205410588533
# ====> Epoch: 394 Average loss: 0.0205
# 395 0.0204910989851
# ====> Epoch: 395 Average loss: 0.0205
# 396 0.0204715225846
# ====> Epoch: 396 Average loss: 0.0205
# 397 0.0204792190343
# ====> Epoch: 397 Average loss: 0.0205
# 398 0.0204910282046
# ====> Epoch: 398 Average loss: 0.0205
# 399 0.0204624515027
# ====> Epoch: 399 Average loss: 0.0205
# 400 0.0204510241747
# ====> Epoch: 400 Average loss: 0.0205
# 401 0.0204298458993
# ====> Epoch: 401 Average loss: 0.0204
# 402 0.0204229205847
# ====> Epoch: 402 Average loss: 0.0204
# 403 0.0204398036003
# ====> Epoch: 403 Average loss: 0.0204
# 404 0.0203996244818
# ====> Epoch: 404 Average loss: 0.0204
# 405 0.0203915257007
# ====> Epoch: 405 Average loss: 0.0204
# 406 0.0203847549856
# ====> Epoch: 406 Average loss: 0.0204
# 407 0.0203842762858
# ====> Epoch: 407 Average loss: 0.0204
# 408 0.0203963574022
# ====> Epoch: 408 Average loss: 0.0204
# 409 0.0203881114721
# ====> Epoch: 409 Average loss: 0.0204
# 410 0.0203757155687
# ====> Epoch: 410 Average loss: 0.0204
# 411 0.0203548073769
# ====> Epoch: 411 Average loss: 0.0204
# 412 0.0203485991806
# ====> Epoch: 412 Average loss: 0.0203
# 413 0.0203397702426
# ====> Epoch: 413 Average loss: 0.0203
# 414 0.0203476715833
# ====> Epoch: 414 Average loss: 0.0203
# 415 0.0203586090356
# ====> Epoch: 415 Average loss: 0.0204
# 416 0.0203728415072
# ====> Epoch: 416 Average loss: 0.0204
# 417 0.0203621257097
# ====> Epoch: 417 Average loss: 0.0204
# 418 0.0203491467983
# ====> Epoch: 418 Average loss: 0.0203
# 419 0.0203516222537
# ====> Epoch: 419 Average loss: 0.0204
# 420 0.020332403481
# ====> Epoch: 420 Average loss: 0.0203
# 421 0.0203204993159
# ====> Epoch: 421 Average loss: 0.0203
# 422 0.0203218720853
# ====> Epoch: 422 Average loss: 0.0203
# 423 0.0203466806561
# ====> Epoch: 423 Average loss: 0.0203
# 424 0.0203993897885
# ====> Epoch: 424 Average loss: 0.0204
# 425 0.0203144103289
# ====> Epoch: 425 Average loss: 0.0203
# 426 0.0203144773841
# ====> Epoch: 426 Average loss: 0.0203
# 427 0.0203105583787
# ====> Epoch: 427 Average loss: 0.0203
# 428 0.0202935822308
# ====> Epoch: 428 Average loss: 0.0203
# 429 0.0202821344137
# ====> Epoch: 429 Average loss: 0.0203
# 430 0.0202899388969
# ====> Epoch: 430 Average loss: 0.0203
# 431 0.0203463993967
# ====> Epoch: 431 Average loss: 0.0203
# 432 0.0203392338008
# ====> Epoch: 432 Average loss: 0.0203
# 433 0.0203767903149
# ====> Epoch: 433 Average loss: 0.0204
# 434 0.0203966181725
# ====> Epoch: 434 Average loss: 0.0204
# 435 0.0204103719443
# ====> Epoch: 435 Average loss: 0.0204
# 436 0.0203746203333
# ====> Epoch: 436 Average loss: 0.0204
# 437 0.0203894842416
# ====> Epoch: 437 Average loss: 0.0204
# 438 0.0203470718116
# ====> Epoch: 438 Average loss: 0.0203
# 439 0.0203345213085
# ====> Epoch: 439 Average loss: 0.0203
# 440 0.0202951543033
# ====> Epoch: 440 Average loss: 0.0203
# 441 0.0202859044075
# ====> Epoch: 441 Average loss: 0.0203
# 442 0.0202790647745
# ====> Epoch: 442 Average loss: 0.0203
# 443 0.020288201049
# ====> Epoch: 443 Average loss: 0.0203
# 444 0.0202887523919
# ====> Epoch: 444 Average loss: 0.0203
# 445 0.0202482491732
# ====> Epoch: 445 Average loss: 0.0202
# 446 0.0202154070139
# ====> Epoch: 446 Average loss: 0.0202
# 447 0.0202139671892
# ====> Epoch: 447 Average loss: 0.0202
# 448 0.0202255472541
# ====> Epoch: 448 Average loss: 0.0202
# 449 0.0202044248581
# ====> Epoch: 449 Average loss: 0.0202
# 450 0.0202038735151
# ====> Epoch: 450 Average loss: 0.0202
# 451 0.0201769210398
# ====> Epoch: 451 Average loss: 0.0202
# 452 0.0201560929418
# ====> Epoch: 452 Average loss: 0.0202
# 453 0.020143777132
# ====> Epoch: 453 Average loss: 0.0201
# 454 0.020241972059
# ====> Epoch: 454 Average loss: 0.0202
# 455 0.0201397165656
# ====> Epoch: 455 Average loss: 0.0201
# 456 0.0201114248484
# ====> Epoch: 456 Average loss: 0.0201
# 457 0.0201003812253
# ====> Epoch: 457 Average loss: 0.0201
# 458 0.0200975127518
# ====> Epoch: 458 Average loss: 0.0201
# 459 0.0200803205371
# ====> Epoch: 459 Average loss: 0.0201
# 460 0.0200777128339
# ====> Epoch: 460 Average loss: 0.0201
# 461 0.0200781673193
# ====> Epoch: 461 Average loss: 0.0201
# 462 0.0200690869242
# ====> Epoch: 462 Average loss: 0.0201
# 463 0.0200620237738
# ====> Epoch: 463 Average loss: 0.0201
# 464 0.0200598351657
# ====> Epoch: 464 Average loss: 0.0201
# 465 0.0200578942895
# ====> Epoch: 465 Average loss: 0.0201
# 466 0.0200422909111
# ====> Epoch: 466 Average loss: 0.0200
# 467 0.0200698710978
# ====> Epoch: 467 Average loss: 0.0201
# 468 0.0200819913298
# ====> Epoch: 468 Average loss: 0.0201
# 469 0.02011019364
# ====> Epoch: 469 Average loss: 0.0201
# 470 0.0201369766146
# ====> Epoch: 470 Average loss: 0.0201
# 471 0.020149089396
# ====> Epoch: 471 Average loss: 0.0201
# 472 0.0201441776007
# ====> Epoch: 472 Average loss: 0.0201
# 473 0.0200904104859
# ====> Epoch: 473 Average loss: 0.0201
# 474 0.0200516469777
# ====> Epoch: 474 Average loss: 0.0201
# 475 0.020040858537
# ====> Epoch: 475 Average loss: 0.0200
# 476 0.020041320473
# ====> Epoch: 476 Average loss: 0.0200
# 477 0.0200771838427
# ====> Epoch: 477 Average loss: 0.0201
# 478 0.0200615618378
# ====> Epoch: 478 Average loss: 0.0201
# 479 0.0200306177139
# ====> Epoch: 479 Average loss: 0.0200
# 480 0.0200123544782
# ====> Epoch: 480 Average loss: 0.0200
# 481 0.0199950579554
# ====> Epoch: 481 Average loss: 0.0200
# 482 0.0199953168631
# ====> Epoch: 482 Average loss: 0.0200
# 483 0.0200199503452
# ====> Epoch: 483 Average loss: 0.0200
# 484 0.0200037453324
# ====> Epoch: 484 Average loss: 0.0200
# 485 0.0200329143554
# ====> Epoch: 485 Average loss: 0.0200
# 486 0.0200330540538
# ====> Epoch: 486 Average loss: 0.0200
# 487 0.0200115386397
# ====> Epoch: 487 Average loss: 0.0200
# 488 0.0199988726526
# ====> Epoch: 488 Average loss: 0.0200
# 489 0.0200032256544
# ====> Epoch: 489 Average loss: 0.0200
# 490 0.0200004428625
# ====> Epoch: 490 Average loss: 0.0200
# 491 0.0199966467917
# ====> Epoch: 491 Average loss: 0.0200
# 492 0.0200009271502
# ====> Epoch: 492 Average loss: 0.0200
# 493 0.0199945643544
# ====> Epoch: 493 Average loss: 0.0200
# 494 0.0200158264488
# ====> Epoch: 494 Average loss: 0.0200
# 495 0.0200161803514
# ====> Epoch: 495 Average loss: 0.0200
# 496 0.0200033523142
# ====> Epoch: 496 Average loss: 0.0200
# 497 0.0199760254472
# ====> Epoch: 497 Average loss: 0.0200
# 498 0.0199516769499
# ====> Epoch: 498 Average loss: 0.0200
# 499 0.0199285335839
# ====> Epoch: 499 Average loss: 0.0199
# 500 0.0199179779738
# ====> Epoch: 500 Average loss: 0.0199
# 501 0.0199145805091
# ====> Epoch: 501 Average loss: 0.0199
# 502 0.0199189353734
# ====> Epoch: 502 Average loss: 0.0199
# 503 0.0199150964618
# ====> Epoch: 503 Average loss: 0.0199
# 504 0.019920764491
# ====> Epoch: 504 Average loss: 0.0199
# 505 0.0199103076011
# ====> Epoch: 505 Average loss: 0.0199
# 506 0.0199040062726
# ====> Epoch: 506 Average loss: 0.0199
# 507 0.0199029613286
# ====> Epoch: 507 Average loss: 0.0199
# 508 0.0199161693454
# ====> Epoch: 508 Average loss: 0.0199
# 509 0.0199489574879
# ====> Epoch: 509 Average loss: 0.0199
# 510 0.0200144741684
# ====> Epoch: 510 Average loss: 0.0200
# 511 0.0200753789395
# ====> Epoch: 511 Average loss: 0.0201
# 512 0.0201282948256
# ====> Epoch: 512 Average loss: 0.0201
# 513 0.0200867261738
# ====> Epoch: 513 Average loss: 0.0201
# 514 0.0200054720044
# ====> Epoch: 514 Average loss: 0.0200
# 515 0.0199023447931
# ====> Epoch: 515 Average loss: 0.0199
# 516 0.0199078917503
# ====> Epoch: 516 Average loss: 0.0199
# 517 0.0199517942965
# ====> Epoch: 517 Average loss: 0.0200
# 518 0.0199690703303
# ====> Epoch: 518 Average loss: 0.0200
# 519 0.0199137851596
# ====> Epoch: 519 Average loss: 0.0199
# 520 0.0198570471257
# ====> Epoch: 520 Average loss: 0.0199
# 521 0.0198608171195
# ====> Epoch: 521 Average loss: 0.0199
# 522 0.0198871102184
# ====> Epoch: 522 Average loss: 0.0199
# 523 0.0198861975223
# ====> Epoch: 523 Average loss: 0.0199
# 524 0.0198587942868
# ====> Epoch: 524 Average loss: 0.0199
# 525 0.0198217835277
# ====> Epoch: 525 Average loss: 0.0198
# 526 0.0198317654431
# ====> Epoch: 526 Average loss: 0.0198
# 527 0.0198388919234
# ====> Epoch: 527 Average loss: 0.0198
# 528 0.0198446456343
# ====> Epoch: 528 Average loss: 0.0198
# 529 0.019816512242
# ====> Epoch: 529 Average loss: 0.0198
# 530 0.0198043137789
# ====> Epoch: 530 Average loss: 0.0198
# 531 0.0198031570762
# ====> Epoch: 531 Average loss: 0.0198
# 532 0.0198084339499
# ====> Epoch: 532 Average loss: 0.0198
# 533 0.0198620073497
# ====> Epoch: 533 Average loss: 0.0199
# 534 0.0197939053178
# ====> Epoch: 534 Average loss: 0.0198
# 535 0.0197975095361
# ====> Epoch: 535 Average loss: 0.0198
# 536 0.0198151469231
# ====> Epoch: 536 Average loss: 0.0198
# 537 0.0197979286313
# ====> Epoch: 537 Average loss: 0.0198
# 538 0.0197965577245
# ====> Epoch: 538 Average loss: 0.0198
# 539 0.0198105368763
# ====> Epoch: 539 Average loss: 0.0198
# 540 0.0198227483779
# ====> Epoch: 540 Average loss: 0.0198
# 541 0.0198366679251
# ====> Epoch: 541 Average loss: 0.0198
# 542 0.0198575090617
# ====> Epoch: 542 Average loss: 0.0199
# 543 0.019827708602
# ====> Epoch: 543 Average loss: 0.0198
# 544 0.0198182184249
# ====> Epoch: 544 Average loss: 0.0198
# 545 0.0198128446937
# ====> Epoch: 545 Average loss: 0.0198
# 546 0.0198108963668
# ====> Epoch: 546 Average loss: 0.0198
# 547 0.0198543462902
# ====> Epoch: 547 Average loss: 0.0199
# 548 0.0198131408542
# ====> Epoch: 548 Average loss: 0.0198
# 549 0.019822832197
# ====> Epoch: 549 Average loss: 0.0198
# 550 0.0198235958815
# ====> Epoch: 550 Average loss: 0.0198
# 551 0.0198402181268
# ====> Epoch: 551 Average loss: 0.0198
# 552 0.0198512598872
# ====> Epoch: 552 Average loss: 0.0199
# 553 0.0198816359043
# ====> Epoch: 553 Average loss: 0.0199
# 554 0.0198961980641
# ====> Epoch: 554 Average loss: 0.0199
# 555 0.0199212580919
# ====> Epoch: 555 Average loss: 0.0199
# 556 0.0199151486158
# ====> Epoch: 556 Average loss: 0.0199
# 557 0.0199087299407
# ====> Epoch: 557 Average loss: 0.0199
# 558 0.0198840610683
# ====> Epoch: 558 Average loss: 0.0199
# 559 0.0198479518294
# ====> Epoch: 559 Average loss: 0.0198
# 560 0.0198105312884
# ====> Epoch: 560 Average loss: 0.0198
# 561 0.0197909474373
# ====> Epoch: 561 Average loss: 0.0198
# 562 0.0197816658765
# ====> Epoch: 562 Average loss: 0.0198
# 563 0.0197912734002
# ====> Epoch: 563 Average loss: 0.0198
# 564 0.0198017861694
# ====> Epoch: 564 Average loss: 0.0198
# 565 0.019777989015
# ====> Epoch: 565 Average loss: 0.0198
# 566 0.0197578649968
# ====> Epoch: 566 Average loss: 0.0198
# 567 0.019740793854
# ====> Epoch: 567 Average loss: 0.0197
# 568 0.0197313819081
# ====> Epoch: 568 Average loss: 0.0197
# 569 0.0197381414473
# ====> Epoch: 569 Average loss: 0.0197
# 570 0.0197458975017
# ====> Epoch: 570 Average loss: 0.0197
# 571 0.0197390522808
# ====> Epoch: 571 Average loss: 0.0197
# 572 0.0197181552649
# ====> Epoch: 572 Average loss: 0.0197
# 573 0.0197093505412
# ====> Epoch: 573 Average loss: 0.0197
# 574 0.0197034422308
# ====> Epoch: 574 Average loss: 0.0197
# 575 0.0197070445865
# ====> Epoch: 575 Average loss: 0.0197
# 576 0.0197012014687
# ====> Epoch: 576 Average loss: 0.0197
# 577 0.0197064522654
# ====> Epoch: 577 Average loss: 0.0197
# 578 0.0196983870119
# ====> Epoch: 578 Average loss: 0.0197
# 579 0.0197006445378
# ====> Epoch: 579 Average loss: 0.0197
# 580 0.0196902472526
# ====> Epoch: 580 Average loss: 0.0197
# 581 0.019685620442
# ====> Epoch: 581 Average loss: 0.0197
# 582 0.0196852125227
# ====> Epoch: 582 Average loss: 0.0197
# 583 0.0196929182857
# ====> Epoch: 583 Average loss: 0.0197
# 584 0.0197334196419
# ====> Epoch: 584 Average loss: 0.0197
# 585 0.0197502393275
# ====> Epoch: 585 Average loss: 0.0198
# 586 0.0198247153312
# ====> Epoch: 586 Average loss: 0.0198
# 587 0.0198885761201
# ====> Epoch: 587 Average loss: 0.0199
# 588 0.0199229549617
# ====> Epoch: 588 Average loss: 0.0199
# 589 0.0199031922966
# ====> Epoch: 589 Average loss: 0.0199
# 590 0.0198030918837
# ====> Epoch: 590 Average loss: 0.0198
# 591 0.0197393782437
# ====> Epoch: 591 Average loss: 0.0197
# 592 0.019771264866
# ====> Epoch: 592 Average loss: 0.0198
# 593 0.0198135059327
# ====> Epoch: 593 Average loss: 0.0198
# 594 0.0198070053011
# ====> Epoch: 594 Average loss: 0.0198
# 595 0.0197524335235
# ====> Epoch: 595 Average loss: 0.0198
# 596 0.0197113137692
# ====> Epoch: 596 Average loss: 0.0197
# 597 0.0197414457798
# ====> Epoch: 597 Average loss: 0.0197
# 598 0.0197650194168
# ====> Epoch: 598 Average loss: 0.0198
# 599 0.0197344217449
# ====> Epoch: 599 Average loss: 0.0197
# 600 0.0196954328567
# ====> Epoch: 600 Average loss: 0.0197
# 601 0.0196897834539
# ====> Epoch: 601 Average loss: 0.0197
# 602 0.0197017174214
# ====> Epoch: 602 Average loss: 0.0197
# 603 0.0197069048882
# ====> Epoch: 603 Average loss: 0.0197
# 604 0.0197005029768
# ====> Epoch: 604 Average loss: 0.0197
# 605 0.0196871068329
# ====> Epoch: 605 Average loss: 0.0197
# 606 0.0196798238903
# ====> Epoch: 606 Average loss: 0.0197
# 607 0.0196791775525
# ====> Epoch: 607 Average loss: 0.0197
# 608 0.0197065956891
# ====> Epoch: 608 Average loss: 0.0197
# 609 0.0196736101061
# ====> Epoch: 609 Average loss: 0.0197
# 610 0.0196971651167
# ====> Epoch: 610 Average loss: 0.0197
# 611 0.0196996405721
# ====> Epoch: 611 Average loss: 0.0197
# 612 0.01970339939
# ====> Epoch: 612 Average loss: 0.0197
# 613 0.0197189040482
# ====> Epoch: 613 Average loss: 0.0197
# 614 0.0197068508714
# ====> Epoch: 614 Average loss: 0.0197
# 615 0.0196905564517
# ====> Epoch: 615 Average loss: 0.0197
# 616 0.0196846295148
# ====> Epoch: 616 Average loss: 0.0197
# 617 0.019722763449
# ====> Epoch: 617 Average loss: 0.0197
# 618 0.0197118446231
# ====> Epoch: 618 Average loss: 0.0197
# 619 0.0197413042188
# ====> Epoch: 619 Average loss: 0.0197
# 620 0.0197396893054
# ====> Epoch: 620 Average loss: 0.0197
# 621 0.0197807718068
# ====> Epoch: 621 Average loss: 0.0198
# 622 0.0197828747332
# ====> Epoch: 622 Average loss: 0.0198
# 623 0.0198055393994
# ====> Epoch: 623 Average loss: 0.0198
# 624 0.0198528580368
# ====> Epoch: 624 Average loss: 0.0199
# 625 0.0199259854853
# ====> Epoch: 625 Average loss: 0.0199
# 626 0.0199642218649
# ====> Epoch: 626 Average loss: 0.0200
# 627 0.019919142127
# ====> Epoch: 627 Average loss: 0.0199
# 628 0.0198317933828
# ====> Epoch: 628 Average loss: 0.0198
# 629 0.0197225622833
# ====> Epoch: 629 Average loss: 0.0197
# 630 0.0197299495339
# ====> Epoch: 630 Average loss: 0.0197
# 631 0.0198064763099
# ====> Epoch: 631 Average loss: 0.0198
# 632 0.0197912734002
# ====> Epoch: 632 Average loss: 0.0198
# 633 0.0197738651186
# ====> Epoch: 633 Average loss: 0.0198
# 634 0.0197101291269
# ====> Epoch: 634 Average loss: 0.0197
# 635 0.0197200197726
# ====> Epoch: 635 Average loss: 0.0197
# 636 0.0197329092771
# ====> Epoch: 636 Average loss: 0.0197
# 637 0.0197354182601
# ====> Epoch: 637 Average loss: 0.0197
# 638 0.0196945108473
# ====> Epoch: 638 Average loss: 0.0197
# 639 0.0196658056229
# ====> Epoch: 639 Average loss: 0.0197
# 640 0.0196847599
# ====> Epoch: 640 Average loss: 0.0197
# 641 0.0196826215833
# ====> Epoch: 641 Average loss: 0.0197
# 642 0.0196510795504
# ====> Epoch: 642 Average loss: 0.0197
# 643 0.0196233838797
# ====> Epoch: 643 Average loss: 0.0196
# 644 0.0196298286319
# ====> Epoch: 644 Average loss: 0.0196
# 645 0.01963108778
# ====> Epoch: 645 Average loss: 0.0196
# 646 0.0196236204356
# ====> Epoch: 646 Average loss: 0.0196
# 647 0.0196051541716
# ====> Epoch: 647 Average loss: 0.0196
# 648 0.019603420049
# ====> Epoch: 648 Average loss: 0.0196
# 649 0.0196000430733
# ====> Epoch: 649 Average loss: 0.0196
# 650 0.0195971727371
# ====> Epoch: 650 Average loss: 0.0196
# 651 0.019593546167
# ====> Epoch: 651 Average loss: 0.0196
# 652 0.0195863153785
# ====> Epoch: 652 Average loss: 0.0196
# 653 0.019570633769
# ====> Epoch: 653 Average loss: 0.0196
# 654 0.0195672456175
# ====> Epoch: 654 Average loss: 0.0196
# 655 0.0195631794631
# ====> Epoch: 655 Average loss: 0.0196
# 656 0.0195647627115
# ====> Epoch: 656 Average loss: 0.0196
# 657 0.0195749048144
# ====> Epoch: 657 Average loss: 0.0196
# 658 0.0195570234209
# ====> Epoch: 658 Average loss: 0.0196
# 659 0.0195503719151
# ====> Epoch: 659 Average loss: 0.0196
# 660 0.0195414479822
# ====> Epoch: 660 Average loss: 0.0195
# 661 0.019537486136
# ====> Epoch: 661 Average loss: 0.0195
# 662 0.0195294786245
# ====> Epoch: 662 Average loss: 0.0195
# 663 0.0195196773857
# ====> Epoch: 663 Average loss: 0.0195
# 664 0.0195182543248
# ====> Epoch: 664 Average loss: 0.0195
# 665 0.0195235311985
# ====> Epoch: 665 Average loss: 0.0195
# 666 0.0195266138762
# ====> Epoch: 666 Average loss: 0.0195
# 667 0.0195321366191
# ====> Epoch: 667 Average loss: 0.0195
# 668 0.0195484105498
# ====> Epoch: 668 Average loss: 0.0195
# 669 0.0196158178151
# ====> Epoch: 669 Average loss: 0.0196
# 670 0.0196186341345
# ====> Epoch: 670 Average loss: 0.0196
# 671 0.0196505300701
# ====> Epoch: 671 Average loss: 0.0197
# 672 0.0196058843285
# ====> Epoch: 672 Average loss: 0.0196
# 673 0.0195776056498
# ====> Epoch: 673 Average loss: 0.0196
# 674 0.0195214506239
# ====> Epoch: 674 Average loss: 0.0195
# 675 0.0194919854403
# ====> Epoch: 675 Average loss: 0.0195
# 676 0.0195135381073
# ====> Epoch: 676 Average loss: 0.0195
# 677 0.0195214226842
# ====> Epoch: 677 Average loss: 0.0195
# 678 0.019536267966
# ====> Epoch: 678 Average loss: 0.0195
# 679 0.0195122994483
# ====> Epoch: 679 Average loss: 0.0195
# 680 0.0194997414947
# ====> Epoch: 680 Average loss: 0.0195
# 681 0.0194813087583
# ====> Epoch: 681 Average loss: 0.0195
# 682 0.0194743331522
# ====> Epoch: 682 Average loss: 0.0195
# 683 0.0194732155651
# ====> Epoch: 683 Average loss: 0.0195
# 684 0.019475646317
# ====> Epoch: 684 Average loss: 0.0195
# 685 0.0194753687829
# ====> Epoch: 685 Average loss: 0.0195
# 686 0.0194714553654
# ====> Epoch: 686 Average loss: 0.0195
# 687 0.0194680802524
# ====> Epoch: 687 Average loss: 0.0195
# 688 0.0194589737803
# ====> Epoch: 688 Average loss: 0.0195
# 689 0.0194627307355
# ====> Epoch: 689 Average loss: 0.0195
# 690 0.0194721333683
# ====> Epoch: 690 Average loss: 0.0195
# 691 0.0194901805371
# ====> Epoch: 691 Average loss: 0.0195
# 692 0.0195075012743
# ====> Epoch: 692 Average loss: 0.0195
# 693 0.0195101834834
# ====> Epoch: 693 Average loss: 0.0195
# 694 0.019510211423
# ====> Epoch: 694 Average loss: 0.0195
# 695 0.01949881576
# ====> Epoch: 695 Average loss: 0.0195
# 696 0.0194792654365
# ====> Epoch: 696 Average loss: 0.0195
# 697 0.0194561854005
# ====> Epoch: 697 Average loss: 0.0195
# 698 0.019449967891
# ====> Epoch: 698 Average loss: 0.0194
# 699 0.0194367654622
# ====> Epoch: 699 Average loss: 0.0194
# 700 0.0194367263466
# ====> Epoch: 700 Average loss: 0.0194
# 701 0.0194315072149
# ====> Epoch: 701 Average loss: 0.0194
# 702 0.0194154176861
# ====> Epoch: 702 Average loss: 0.0194
# 703 0.0194206368178
# ====> Epoch: 703 Average loss: 0.0194
# 704 0.0194135755301
# ====> Epoch: 704 Average loss: 0.0194
# 705 0.0194192361087
# ====> Epoch: 705 Average loss: 0.0194
# 706 0.0194158218801
# ====> Epoch: 706 Average loss: 0.0194
# 707 0.0194140002131
# ====> Epoch: 707 Average loss: 0.0194
# 708 0.0193959884346
# ====> Epoch: 708 Average loss: 0.0194
# 709 0.0194019675255
# ====> Epoch: 709 Average loss: 0.0194
# 710 0.0193818155676
# ====> Epoch: 710 Average loss: 0.0194
# 711 0.0193809550256
# ====> Epoch: 711 Average loss: 0.0194
# 712 0.0193800870329
# ====> Epoch: 712 Average loss: 0.0194
# 713 0.0193857327104
# ====> Epoch: 713 Average loss: 0.0194
# 714 0.0193768348545
# ====> Epoch: 714 Average loss: 0.0194
# 715 0.0193808618933
# ====> Epoch: 715 Average loss: 0.0194
# 716 0.0194042697549
# ====> Epoch: 716 Average loss: 0.0194
# 717 0.0194457117468
# ====> Epoch: 717 Average loss: 0.0194
# 718 0.0195082351565
# ====> Epoch: 718 Average loss: 0.0195
# 719 0.0195566266775
# ====> Epoch: 719 Average loss: 0.0196
# 720 0.0195808671415
# ====> Epoch: 720 Average loss: 0.0196
# 721 0.0195363666862
# ====> Epoch: 721 Average loss: 0.0195
# 722 0.0194614138454
# ====> Epoch: 722 Average loss: 0.0195
# 723 0.019424168393
# ====> Epoch: 723 Average loss: 0.0194
# 724 0.0194548424333
# ====> Epoch: 724 Average loss: 0.0195
# 725 0.0194810573012
# ====> Epoch: 725 Average loss: 0.0195
# 726 0.0194579437375
# ====> Epoch: 726 Average loss: 0.0195
# 727 0.0194457899779
# ====> Epoch: 727 Average loss: 0.0194
# 728 0.0194284822792
# ====> Epoch: 728 Average loss: 0.0194
# 729 0.0194187164307
# ====> Epoch: 729 Average loss: 0.0194
# 730 0.0194230731577
# ====> Epoch: 730 Average loss: 0.0194
# 731 0.0194105431437
# ====> Epoch: 731 Average loss: 0.0194
# 732 0.0193760823458
# ====> Epoch: 732 Average loss: 0.0194
# 733 0.0193602386862
# ====> Epoch: 733 Average loss: 0.0194
# 734 0.0193804968148
# ====> Epoch: 734 Average loss: 0.0194
# 735 0.0193813387305
# ====> Epoch: 735 Average loss: 0.0194
# 736 0.0193686820567
# ====> Epoch: 736 Average loss: 0.0194
# 737 0.0193536505103
# ====> Epoch: 737 Average loss: 0.0194
# 738 0.0193418748677
# ====> Epoch: 738 Average loss: 0.0193
# 739 0.019341127947
# ====> Epoch: 739 Average loss: 0.0193
# 740 0.0193392876536
# ====> Epoch: 740 Average loss: 0.0193
# 741 0.0193333439529
# ====> Epoch: 741 Average loss: 0.0193
# 742 0.0193267595023
# ====> Epoch: 742 Average loss: 0.0193
# 743 0.0193201880902
# ====> Epoch: 743 Average loss: 0.0193
# 744 0.019324624911
# ====> Epoch: 744 Average loss: 0.0193
# 745 0.0193305630237
# ====> Epoch: 745 Average loss: 0.0193
# 746 0.0193268153816
# ====> Epoch: 746 Average loss: 0.0193
# 747 0.0193335097283
# ====> Epoch: 747 Average loss: 0.0193
# 748 0.0193671192974
# ====> Epoch: 748 Average loss: 0.0194
# 749 0.0193578563631
# ====> Epoch: 749 Average loss: 0.0194
# 750 0.0193363875151
# ====> Epoch: 750 Average loss: 0.0193
# 751 0.0193499438465
# ====> Epoch: 751 Average loss: 0.0193
# 752 0.0194065831602
# ====> Epoch: 752 Average loss: 0.0194
# 753 0.0194060765207
# ====> Epoch: 753 Average loss: 0.0194
# 754 0.0194252859801
# ====> Epoch: 754 Average loss: 0.0194
# 755 0.0194412562996
# ====> Epoch: 755 Average loss: 0.0194
# 756 0.0194288231432
# ====> Epoch: 756 Average loss: 0.0194
# 757 0.0193815100938
# ====> Epoch: 757 Average loss: 0.0194
# 758 0.0193561632186
# ====> Epoch: 758 Average loss: 0.0194
# 759 0.0193297043443
# ====> Epoch: 759 Average loss: 0.0193
# 760 0.0193029399961
# ====> Epoch: 760 Average loss: 0.0193
# 761 0.019307192415
# ====> Epoch: 761 Average loss: 0.0193
# 762 0.0193199533969
# ====> Epoch: 762 Average loss: 0.0193
# 763 0.0193351749331
# ====> Epoch: 763 Average loss: 0.0193
# 764 0.0193412713706
# ====> Epoch: 764 Average loss: 0.0193
# 765 0.0193218607455
# ====> Epoch: 765 Average loss: 0.0193
# 766 0.0193027071655
# ====> Epoch: 766 Average loss: 0.0193
# 767 0.0192900020629
# ====> Epoch: 767 Average loss: 0.0193
# 768 0.019281020388
# ====> Epoch: 768 Average loss: 0.0193
# 769 0.0192698221654
# ====> Epoch: 769 Average loss: 0.0193
# 770 0.0192619878799
# ====> Epoch: 770 Average loss: 0.0193
# 771 0.0192723441869
# ====> Epoch: 771 Average loss: 0.0193
# 772 0.0192689821124
# ====> Epoch: 772 Average loss: 0.0193
# 773 0.0192679855973
# ====> Epoch: 773 Average loss: 0.0193
# 774 0.0192690975964
# ====> Epoch: 774 Average loss: 0.0193
# 775 0.0192771423608
# ====> Epoch: 775 Average loss: 0.0193
# 776 0.0192714855075
# ====> Epoch: 776 Average loss: 0.0193
# 777 0.0192634165287
# ====> Epoch: 777 Average loss: 0.0193
# 778 0.019262496382
# ====> Epoch: 778 Average loss: 0.0193
# 779 0.0192518550903
# ====> Epoch: 779 Average loss: 0.0193
# 780 0.0192533321679
# ====> Epoch: 780 Average loss: 0.0193
# 781 0.0192630812526
# ====> Epoch: 781 Average loss: 0.0193
# 782 0.0192689038813
# ====> Epoch: 782 Average loss: 0.0193
# 783 0.0192688945681
# ====> Epoch: 783 Average loss: 0.0193
# 784 0.0192880854011
# ====> Epoch: 784 Average loss: 0.0193
# 785 0.0193047244102
# ====> Epoch: 785 Average loss: 0.0193
# 786 0.0193211343139
# ====> Epoch: 786 Average loss: 0.0193
# 787 0.0193412005901
# ====> Epoch: 787 Average loss: 0.0193
# 788 0.0193198379129
# ====> Epoch: 788 Average loss: 0.0193
# 789 0.0192944146693
# ====> Epoch: 789 Average loss: 0.0193
# 790 0.0192564241588
# ====> Epoch: 790 Average loss: 0.0193
# 791 0.0192441083491
# ====> Epoch: 791 Average loss: 0.0192
# 792 0.0192407742143
# ====> Epoch: 792 Average loss: 0.0192
# 793 0.0192706417292
# ====> Epoch: 793 Average loss: 0.0193
# 794 0.01929342933
# ====> Epoch: 794 Average loss: 0.0193
# 795 0.0192973595113
# ====> Epoch: 795 Average loss: 0.0193
# 796 0.0192916002125
# ====> Epoch: 796 Average loss: 0.0193
# 797 0.0192402563989
# ====> Epoch: 797 Average loss: 0.0192
# 798 0.0192121341825
# ====> Epoch: 798 Average loss: 0.0192
# 799 0.0191964618862
# ====> Epoch: 799 Average loss: 0.0192
# 800 0.0192022006959
# ====> Epoch: 800 Average loss: 0.0192
# 801 0.0192169621587
# ====> Epoch: 801 Average loss: 0.0192
# 802 0.0192213244736
# ====> Epoch: 802 Average loss: 0.0192
# 803 0.0192071255296
# ====> Epoch: 803 Average loss: 0.0192
# 804 0.0191913992167
# ====> Epoch: 804 Average loss: 0.0192
# 805 0.0191833078861
# ====> Epoch: 805 Average loss: 0.0192
# 806 0.0191743187606
# ====> Epoch: 806 Average loss: 0.0192
# 807 0.0191754288971
# ====> Epoch: 807 Average loss: 0.0192
# 808 0.0191860608757
# ====> Epoch: 808 Average loss: 0.0192
# 809 0.0191968865693
# ====> Epoch: 809 Average loss: 0.0192
# 810 0.0192082710564
# ====> Epoch: 810 Average loss: 0.0192
# 811 0.0192069709301
# ====> Epoch: 811 Average loss: 0.0192
# 812 0.0192060340196
# ====> Epoch: 812 Average loss: 0.0192
# 813 0.0192154366523
# ====> Epoch: 813 Average loss: 0.0192
# 814 0.0191752612591
# ====> Epoch: 814 Average loss: 0.0192
# 815 0.0191747136414
# ====> Epoch: 815 Average loss: 0.0192
# 816 0.0191807374358
# ====> Epoch: 816 Average loss: 0.0192
# 817 0.0191761218011
# ====> Epoch: 817 Average loss: 0.0192
# 818 0.0191855598241
# ====> Epoch: 818 Average loss: 0.0192
# 819 0.0192001275718
# ====> Epoch: 819 Average loss: 0.0192
# 820 0.0192108619958
# ====> Epoch: 820 Average loss: 0.0192
# 821 0.0191883239895
# ====> Epoch: 821 Average loss: 0.0192
# 822 0.0191863570362
# ====> Epoch: 822 Average loss: 0.0192
# 823 0.0191647447646
# ====> Epoch: 823 Average loss: 0.0192
# 824 0.019142312929
# ====> Epoch: 824 Average loss: 0.0191
# 825 0.0191306378692
# ====> Epoch: 825 Average loss: 0.0191
# 826 0.0191157627851
# ====> Epoch: 826 Average loss: 0.0191
# 827 0.0191074144095
# ====> Epoch: 827 Average loss: 0.0191
# 828 0.019106304273
# ====> Epoch: 828 Average loss: 0.0191
# 829 0.0191101599485
# ====> Epoch: 829 Average loss: 0.0191
# 830 0.0191075894982
# ====> Epoch: 830 Average loss: 0.0191
# 831 0.0191163625568
# ====> Epoch: 831 Average loss: 0.0191
# 832 0.0191164091229
# ====> Epoch: 832 Average loss: 0.0191
# 833 0.019133200869
# ====> Epoch: 833 Average loss: 0.0191
# 834 0.0191293619573
# ====> Epoch: 834 Average loss: 0.0191
# 835 0.0191370211542
# ====> Epoch: 835 Average loss: 0.0191
# 836 0.0191275142133
# ====> Epoch: 836 Average loss: 0.0191
# 837 0.0191352292895
# ====> Epoch: 837 Average loss: 0.0191
# 838 0.0191601738334
# ====> Epoch: 838 Average loss: 0.0192
# 839 0.0191928371787
# ====> Epoch: 839 Average loss: 0.0192
# 840 0.0192255694419
# ====> Epoch: 840 Average loss: 0.0192
# 841 0.019298478961
# ====> Epoch: 841 Average loss: 0.0193
# 842 0.0193169917911
# ====> Epoch: 842 Average loss: 0.0193
# 843 0.0192826092243
# ====> Epoch: 843 Average loss: 0.0193
# 844 0.0192207153887
# ====> Epoch: 844 Average loss: 0.0192
# 845 0.01914742589
# ====> Epoch: 845 Average loss: 0.0191
# 846 0.0191332157701
# ====> Epoch: 846 Average loss: 0.0191
# 847 0.019149787724
# ====> Epoch: 847 Average loss: 0.0191
# 848 0.0191837418824
# ====> Epoch: 848 Average loss: 0.0192
# 849 0.019148748368
# ====> Epoch: 849 Average loss: 0.0191
# 850 0.0191100165248
# ====> Epoch: 850 Average loss: 0.0191
# 851 0.019094562158
# ====> Epoch: 851 Average loss: 0.0191
# 852 0.019109910354
# ====> Epoch: 852 Average loss: 0.0191
# 853 0.0191083792597
# ====> Epoch: 853 Average loss: 0.0191
# 854 0.0191003531218
# ====> Epoch: 854 Average loss: 0.0191
# 855 0.0190808176994
# ====> Epoch: 855 Average loss: 0.0191
# 856 0.0190624091774
# ====> Epoch: 856 Average loss: 0.0191
# 857 0.0190578158945
# ====> Epoch: 857 Average loss: 0.0191
# 858 0.0190581195056
# ====> Epoch: 858 Average loss: 0.0191
# 859 0.0190610811114
# ====> Epoch: 859 Average loss: 0.0191
# 860 0.0190532896668
# ====> Epoch: 860 Average loss: 0.0191
# 861 0.019035032019
# ====> Epoch: 861 Average loss: 0.0190
# 862 0.0191434659064
# ====> Epoch: 862 Average loss: 0.0191
# 863 0.0190621875226
# ====> Epoch: 863 Average loss: 0.0191
# 864 0.0190328210592
# ====> Epoch: 864 Average loss: 0.0190
# 865 0.0190404411405
# ====> Epoch: 865 Average loss: 0.0190
# 866 0.0190438050777
# ====> Epoch: 866 Average loss: 0.0190
# 867 0.0190394669771
# ====> Epoch: 867 Average loss: 0.0190
# 868 0.0190402660519
# ====> Epoch: 868 Average loss: 0.0190
# 869 0.0190557446331
# ====> Epoch: 869 Average loss: 0.0191
# 870 0.0190580058843
# ====> Epoch: 870 Average loss: 0.0191
# 871 0.0190591756254
# ====> Epoch: 871 Average loss: 0.0191
# 872 0.0190591756254
# ====> Epoch: 872 Average loss: 0.0191
# 873 0.0190980806947
# ====> Epoch: 873 Average loss: 0.0191
# 874 0.0191181246191
# ====> Epoch: 874 Average loss: 0.0191
# 875 0.0191333610564
# ====> Epoch: 875 Average loss: 0.0191
# 876 0.0191463138908
# ====> Epoch: 876 Average loss: 0.0191
# 877 0.0191250182688
# ====> Epoch: 877 Average loss: 0.0191
# 878 0.0191100034863
# ====> Epoch: 878 Average loss: 0.0191
# 879 0.0190773252398
# ====> Epoch: 879 Average loss: 0.0191
# 880 0.0190852899104
# ====> Epoch: 880 Average loss: 0.0191
# 881 0.0190697833896
# ====> Epoch: 881 Average loss: 0.0191
# 882 0.0190913230181
# ====> Epoch: 882 Average loss: 0.0191
# 883 0.0190935358405
# ====> Epoch: 883 Average loss: 0.0191
# 884 0.0190832950175
# ====> Epoch: 884 Average loss: 0.0191
# 885 0.0190582126379
# ====> Epoch: 885 Average loss: 0.0191
# 886 0.0190482977778
# ====> Epoch: 886 Average loss: 0.0190
# 887 0.0190317016095
# ====> Epoch: 887 Average loss: 0.0190
# 888 0.0190338063985
# ====> Epoch: 888 Average loss: 0.0190
# 889 0.019045997411
# ====> Epoch: 889 Average loss: 0.0190
# 890 0.0190502572805
# ====> Epoch: 890 Average loss: 0.0191
# 891 0.0190338939428
# ====> Epoch: 891 Average loss: 0.0190
# 892 0.0190366003662
# ====> Epoch: 892 Average loss: 0.0190
# 893 0.019011946395
# ====> Epoch: 893 Average loss: 0.0190
# 894 0.0190185494721
# ====> Epoch: 894 Average loss: 0.0190
# 895 0.0190283935517
# ====> Epoch: 895 Average loss: 0.0190
# 896 0.0190212186426
# ====> Epoch: 896 Average loss: 0.0190
# 897 0.0190380960703
# ====> Epoch: 897 Average loss: 0.0190
# 898 0.0190147310495
# ====> Epoch: 898 Average loss: 0.0190
# 899 0.0190269034356
# ====> Epoch: 899 Average loss: 0.0190
# 900 0.019019022584
# ====> Epoch: 900 Average loss: 0.0190
# 901 0.0190270747989
# ====> Epoch: 901 Average loss: 0.0190
# 902 0.0190340802073
# ====> Epoch: 902 Average loss: 0.0190
# 903 0.0190582536161
# ====> Epoch: 903 Average loss: 0.0191
# 904 0.0190814640373
# ====> Epoch: 904 Average loss: 0.0191
# 905 0.0191289149225
# ====> Epoch: 905 Average loss: 0.0191
# 906 0.0191691704094
# ====> Epoch: 906 Average loss: 0.0192
# 907 0.0192360877991
# ====> Epoch: 907 Average loss: 0.0192
# 908 0.0192359630018
# ====> Epoch: 908 Average loss: 0.0192
# 909 0.0192167218775
# ====> Epoch: 909 Average loss: 0.0192
# 910 0.0191184282303
# ====> Epoch: 910 Average loss: 0.0191
# 911 0.0190546810627
# ====> Epoch: 911 Average loss: 0.0191
# 912 0.0190311837941
# ====> Epoch: 912 Average loss: 0.0190
# 913 0.0190748143941
# ====> Epoch: 913 Average loss: 0.0191
# 914 0.0191057231277
# ====> Epoch: 914 Average loss: 0.0191
# 915 0.0190835408866
# ====> Epoch: 915 Average loss: 0.0191
# 916 0.019038869068
# ====> Epoch: 916 Average loss: 0.0190
# 917 0.0189986862242
# ====> Epoch: 917 Average loss: 0.0190
# 918 0.0190039612353
# ====> Epoch: 918 Average loss: 0.0190
# 919 0.0190307367593
# ====> Epoch: 919 Average loss: 0.0190
# 920 0.0190337654203
# ====> Epoch: 920 Average loss: 0.0190
# 921 0.0190185084939
# ====> Epoch: 921 Average loss: 0.0190
# 922 0.0190582573414
# ====> Epoch: 922 Average loss: 0.0191
# 923 0.0189923848957
# ====> Epoch: 923 Average loss: 0.0190
# 924 0.0189960002899
# ====> Epoch: 924 Average loss: 0.0190
# 925 0.0189876519144
# ====> Epoch: 925 Average loss: 0.0190
# 926 0.0189884193242
# ====> Epoch: 926 Average loss: 0.0190
# 927 0.0189842246473
# ====> Epoch: 927 Average loss: 0.0190
# 928 0.0189737621695
# ====> Epoch: 928 Average loss: 0.0190
# 929 0.0189629402012
# ====> Epoch: 929 Average loss: 0.0190
# 930 0.01897267811
# ====> Epoch: 930 Average loss: 0.0190
# 931 0.0189577564597
# ====> Epoch: 931 Average loss: 0.0190
# 932 0.0189806483686
# ====> Epoch: 932 Average loss: 0.0190
# 933 0.0189724322408
# ====> Epoch: 933 Average loss: 0.0190
# 934 0.0189810749143
# ====> Epoch: 934 Average loss: 0.0190
# 935 0.0189849417657
# ====> Epoch: 935 Average loss: 0.0190
# 936 0.0189847946167
# ====> Epoch: 936 Average loss: 0.0190
# 937 0.0189848970622
# ====> Epoch: 937 Average loss: 0.0190
# 938 0.0189943071455
# ====> Epoch: 938 Average loss: 0.0190
# 939 0.018985837698
# ====> Epoch: 939 Average loss: 0.0190
# 940 0.0189976971596
# ====> Epoch: 940 Average loss: 0.0190
# 941 0.0190017595887
# ====> Epoch: 941 Average loss: 0.0190
# 942 0.0190171245486
# ====> Epoch: 942 Average loss: 0.0190
# 943 0.0190318711102
# ====> Epoch: 943 Average loss: 0.0190
# 944 0.0190456584096
# ====> Epoch: 944 Average loss: 0.0190
# 945 0.0190665572882
# ====> Epoch: 945 Average loss: 0.0191
# 946 0.0190578643233
# ====> Epoch: 946 Average loss: 0.0191
# 947 0.0190351177007
# ====> Epoch: 947 Average loss: 0.0190
# 948 0.0190040245652
# ====> Epoch: 948 Average loss: 0.0190
# 949 0.0189853273332
# ====> Epoch: 949 Average loss: 0.0190
# 950 0.01898012124
# ====> Epoch: 950 Average loss: 0.0190
# 951 0.0189757365733
# ====> Epoch: 951 Average loss: 0.0190
# 952 0.018960043788
# ====> Epoch: 952 Average loss: 0.0190
# 953 0.0189548917115
# ====> Epoch: 953 Average loss: 0.0190
# 954 0.0189427044243
# ====> Epoch: 954 Average loss: 0.0189
# 955 0.0189490597695
# ====> Epoch: 955 Average loss: 0.0189
# 956 0.018941167742
# ====> Epoch: 956 Average loss: 0.0189
# 957 0.0189435537905
# ====> Epoch: 957 Average loss: 0.0189
# 958 0.018936432898
# ====> Epoch: 958 Average loss: 0.0189
# 959 0.0189334303141
# ====> Epoch: 959 Average loss: 0.0189
# 960 0.0189280807972
# ====> Epoch: 960 Average loss: 0.0189
# 961 0.0189290232956
# ====> Epoch: 961 Average loss: 0.0189
# 962 0.0189204011112
# ====> Epoch: 962 Average loss: 0.0189
# 963 0.0189266055822
# ====> Epoch: 963 Average loss: 0.0189
# 964 0.0189224667847
# ====> Epoch: 964 Average loss: 0.0189
# 965 0.0189199578017
# ====> Epoch: 965 Average loss: 0.0189
# 966 0.0189177766442
# ====> Epoch: 966 Average loss: 0.0189
# 967 0.0189114343375
# ====> Epoch: 967 Average loss: 0.0189
# 968 0.0189103782177
# ====> Epoch: 968 Average loss: 0.0189
# 969 0.0189032666385
# ====> Epoch: 969 Average loss: 0.0189
# 970 0.0188989397138
# ====> Epoch: 970 Average loss: 0.0189
# 971 0.0189012084156
# ====> Epoch: 971 Average loss: 0.0189
# 972 0.0189057718962
# ====> Epoch: 972 Average loss: 0.0189
# 973 0.0189629532397
# ====> Epoch: 973 Average loss: 0.0190
# 974 0.0189493261278
# ====> Epoch: 974 Average loss: 0.0189
# 975 0.0190053544939
# ====> Epoch: 975 Average loss: 0.0190
# 976 0.0190479625016
# ====> Epoch: 976 Average loss: 0.0190
# 977 0.019111469388
# ====> Epoch: 977 Average loss: 0.0191
# 978 0.0191432870924
# ====> Epoch: 978 Average loss: 0.0191
# 979 0.0191534608603
# ====> Epoch: 979 Average loss: 0.0192
# 980 0.0190678052604
# ====> Epoch: 980 Average loss: 0.0191
# 981 0.0190002918243
# ====> Epoch: 981 Average loss: 0.0190
# 982 0.0189551748335
# ====> Epoch: 982 Average loss: 0.0190
# 983 0.0189683232456
# ====> Epoch: 983 Average loss: 0.0190
# 984 0.0189933665097
# ====> Epoch: 984 Average loss: 0.0190
# 985 0.0189936123788
# ====> Epoch: 985 Average loss: 0.0190
# 986 0.0189736094326
# ====> Epoch: 986 Average loss: 0.0190
# 987 0.0189318750054
# ====> Epoch: 987 Average loss: 0.0189
# 988 0.0189222265035
# ====> Epoch: 988 Average loss: 0.0189
# 989 0.018940538168
# ====> Epoch: 989 Average loss: 0.0189
# 990 0.0189496353269
# ====> Epoch: 990 Average loss: 0.0189
# 991 0.0189240016043
# ====> Epoch: 991 Average loss: 0.0189
# 992 0.0189580433071
# ====> Epoch: 992 Average loss: 0.0190
# 993 0.0189188290387
# ====> Epoch: 993 Average loss: 0.0189
# 994 0.0189256519079
# ====> Epoch: 994 Average loss: 0.0189
# 995 0.0189393330365
# ====> Epoch: 995 Average loss: 0.0189
# 996 0.0189282428473
# ====> Epoch: 996 Average loss: 0.0189
# 997 0.0189210511744
# ====> Epoch: 997 Average loss: 0.0189
# 998 0.0189110562205
# ====> Epoch: 998 Average loss: 0.0189
# 999 0.0189189519733
# ====> Epoch: 999 Average loss: 0.0189

# %%
sr = 22050

# %%
with torch.no_grad():
    sample = cqt_clips[9]
    sample = torch.from_numpy(sample)
    sample = torch.transpose(sample, 0, 1)
    sample = sample.contiguous().view(1, -1, freq_filters*time_steps)
    sample = sample.to(device, dtype=torch.float)
    z = model.encode(sample)
    sample = model.decode(z).cpu()
    sample = sample.view(1, time_steps, freq_filters)
    sample = torch.transpose(sample, 1, 2)
    librosa.display.specshow(librosa.amplitude_to_db(sample[0], ref=np.max), sr=sr, x_axis='time', y_axis='cqt_note')

# %%
librosa.display.specshow(librosa.amplitude_to_db(cqt_clips[9], ref=np.max), sr=sr, x_axis='time', y_axis='cqt_note')
